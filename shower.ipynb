# %%
# Import functions
import setGPU0
from io_functions import *
from draw_functions import *
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is disabled, cuDNN not available)
# Using Theano backend.
# Couldn't import dot_parser, loading of dot files will not be possible.
# using gpu0

# %%
# 1 is signal; 0 is background
train_data, test_data, train_labels, test_labels = train_test(shape=(10000,), split=0.33)

# %%
sig = train_data[np.where(train_labels==1)]
bkg = train_data[np.where(train_labels==0)]

# %%
plt.imshow(np.sum(sig[23].reshape(20,20,25), axis=0))
plt.show()
plt.imshow(np.sum(sig[23].reshape(20,20,25), axis=1))
plt.show()
plt.imshow(np.sum(sig[23].reshape(20,20,25), axis=2))
plt.show()

# %%
plt.imshow(np.sum(bkg[23].reshape(20,20,25), axis=0))
plt.show()
plt.imshow(np.sum(bkg[23].reshape(20,20,25), axis=1))
plt.show()
plt.imshow(np.sum(bkg[23].reshape(20,20,25), axis=2))
plt.show()
